# %%
import Global_Functions as gf
import numpy as np
import matplotlib.pyplot as plt

SAVE_FOLDER = "../Images/Comparison/Steepness/"
gf.check_folder(SAVE_FOLDER)
# Out:
# Folder already exists.

# %%
steepness_levels = [1, 3, 5, 10, 20]

# %%
def convert_results_to_np_array(results = None):
    data = [x[1:-1] for x in results['rmse']]
    data.sort()
    cut_point = int(len(data) * 0.05)
    return np.array(data, dtype = 'float')

# %%
def convert_theory_results_to_np_array(results = None):
    data = [x for x in results['el_RMSE']]
    data.sort()
    cut_point = int(len(data) * 0.05)
    return np.array(data, dtype = 'float')

# %%
def convert_loss_results_to_np_array(results = None):
    for i in range(len(results['tgds'])):
        data = results['rmse'][0][1:-1].split(", ")
    data.sort()
    cut_point = int(len(data) * 0.05)
    return np.array(data, dtype = 'float')

# %%
# experiments with 50-20 on 40-0-1
results_theory = gf.open_CSV_file('../Images/Theoretical_Approach/2021-07-04_10-09/99_results.csv')
results_rnn = gf.open_CSV_file('../Images/Data_Baseline/2021-07-06_23-31/99_results.csv')
results_input = gf.open_CSV_file('../Images/Difference_add_scaled/2021-07-06_23-33/99_results.csv')
results_output = gf.open_CSV_file('../Images/Difference_predict_scaled/2021-07-06_23-34/99_results.csv')
results_loss = gf.open_CSV_file('../Images/Loss_function/Scaled/2021-07-09_11-19/99_results.csv') # still left

theory_1 = convert_theory_results_to_np_array(results_theory)
rnn_1 = convert_results_to_np_array(results_rnn)
add_1 = convert_results_to_np_array(results_input)
out_1 = convert_results_to_np_array(results_output)
loss_1 = convert_loss_results_to_np_array(results_loss)

# %%
# experiments with 50-20 on 40-0-1
results_theory = gf.open_CSV_file('../Images/Theoretical_Approach/2021-07-10_19-57/99_results.csv')
results_rnn = gf.open_CSV_file('../Images/Data_Baseline/2021-07-10_22-56/99_results.csv')
results_input = gf.open_CSV_file('../Images/Difference_add_scaled/2021-07-10_22-57/99_results.csv')
results_output = gf.open_CSV_file('../Images/Difference_predict_scaled/2021-07-10_22-57/99_results.csv')
results_loss = gf.open_CSV_file('../Images/Loss_function/Scaled/2021-07-10_22-57/99_results.csv') # still left

theory_3 = convert_theory_results_to_np_array(results_theory)
rnn_3 = convert_results_to_np_array(results_rnn)
add_3 = convert_results_to_np_array(results_input)
out_3 = convert_results_to_np_array(results_output)
loss_3 = convert_loss_results_to_np_array(results_loss)

# %%
# experiments with 50-20 on 40-0-5
results_theory = gf.open_CSV_file('../Images/Theoretical_Approach/2021-07-04_09-36/99_results.csv')
results_rnn = gf.open_CSV_file('../Images/Data_Baseline/2021-07-09_07-17/99_results.csv')
results_input = gf.open_CSV_file('../Images/Difference_add_scaled/2021-07-09_07-18/99_results.csv')
results_output = gf.open_CSV_file('../Images/Difference_predict_scaled/2021-07-09_07-19/99_results.csv')
results_loss = gf.open_CSV_file('../Images/Loss_function/Scaled/2021-07-10_08-10/99_results.csv') # still left

theory_5 = convert_theory_results_to_np_array(results_theory)
rnn_5 = convert_results_to_np_array(results_rnn)
add_5 = convert_results_to_np_array(results_input)
out_5 = convert_results_to_np_array(results_output)
loss_5 = convert_loss_results_to_np_array(results_loss)

# %%
# experiments with 50-20 on 40-0-10
results_theory = gf.open_CSV_file('../Images/Theoretical_Approach/2021-07-02_11-22/99_results.csv')
results_rnn = gf.open_CSV_file('../Images/Data_Baseline/2021-07-03_11-03/99_results.csv')
results_input = gf.open_CSV_file('../Images/Difference_add_scaled/2021-07-03_11-03/99_results.csv')
results_output = gf.open_CSV_file('../Images/Difference_predict_scaled/2021-07-04_08-36/99_results.csv')
results_loss = gf.open_CSV_file('../Images/Loss_function/Scaled/2021-07-06_23-30/99_results.csv')

theory_10 = convert_theory_results_to_np_array(results_theory)
rnn_10 = convert_results_to_np_array(results_rnn)
add_10 = convert_results_to_np_array(results_input)
out_10 = convert_results_to_np_array(results_output)
loss_10 = convert_loss_results_to_np_array(results_loss)

# %%
# experiments with 50-20 on 40-0-20
results_theory = gf.open_CSV_file('../Images/Theoretical_Approach/2021-07-07_12-23/99_results.csv')
results_rnn = gf.open_CSV_file('../Images/Data_Baseline/2021-07-04_08-35/99_results.csv')
results_input = gf.open_CSV_file('../Images/Difference_add_scaled/2021-07-04_08-37/99_results.csv')
results_output = gf.open_CSV_file('../Images/Difference_predict_scaled/2021-07-03_11-04/99_results.csv')
results_loss = gf.open_CSV_file('../Images/Loss_function/Scaled/2021-07-09_20-42/99_results.csv') #still left

theory_20 = convert_theory_results_to_np_array(results_theory)
rnn_20 = convert_results_to_np_array(results_rnn)
add_20 = convert_results_to_np_array(results_input)
out_20 = convert_results_to_np_array(results_output)
loss_20 = convert_loss_results_to_np_array(results_loss)

# %%
theory = [theory_1, theory_3, theory_5, theory_10, theory_20]
rnn = [rnn_1, rnn_3, rnn_5, rnn_10, rnn_20]
add = [add_1, add_3, add_5, add_10, add_20]
out = [out_1, out_3, out_5, out_10, out_20]
loss = [loss_1, [324.5], loss_5, loss_10, loss_20]

# %%
def box_plot(data, edge_color, fill_color, spec):
     ax.plot([1, 3, 5, 10, 20], [np.mean(data[0]), np.mean(data[1]), np.mean(data[2]), np.mean(data[3]), np.mean(data[4])], color = edge_color, label = spec, linewidth = 2, marker = 's')

# %%
fig, ax = plt.subplots(figsize = (15,10))
ax.set_title('Average RMSE for different Steepness levels ', fontsize = 25)
ax.set_xlabel('Steepness', fontsize = 18)
ax.set_ylabel('Avg. RMSE', fontsize = 18)
ax.yaxis.grid(True)

box_plot(theory, gf.get_color("grey"), gf.get_color("grey"), "Theory")
box_plot(rnn, gf.get_color("blue"), gf.get_color("grey"), "Data Baseline")
box_plot(add, gf.get_color("orange"), gf.get_color("grey"), "DoA- Input")
box_plot(out, gf.get_color("green"), gf.get_color("grey"), "DoA - Output")
box_plot(loss, gf.get_color("red"), gf.get_color("red"), "Loss function")
plt.xticks(size = 14)
plt.yticks(size = 14)
plt.legend(fontsize = 16)
plt.show()

fig.savefig(SAVE_FOLDER + 'comparison.png')
