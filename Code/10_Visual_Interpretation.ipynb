# %%
import numpy as np
import pandas as pd
import Preprocessing as pp
import matplotlib.pyplot as plt

# %%
temp_data_folder = "../Data/Temp_Data/Messdaten_Test_ID_4B/"

# %%
data_power_raw = pp.openCSVFile('power_output_raw.csv', temp_data_folder)
data_power_approx = pp.openCSVFile('power_output_approx.csv', temp_data_folder)
data_drehzahl_raw = pp.openCSVFile('input_drehzahl.csv', temp_data_folder)
data_drehzahl_approx = pp.openCSVFile('approx_drehzahl.csv', temp_data_folder)

# %%
data_4b = pp.openCSVFile('experiment_4b.csv', temp_data_folder)

# %%
plt.scatter(data_4b['input_voltage'], data_4b['spinning_soll'],
            label = "Drehzahl")
plt.xlabel("input_voltage")
plt.ylabel("spinning_measured")
plt.legend(loc='upper left')
plt.show()

# %%
plt.scatter(data_4b['input_voltage'], data_4b['th_power'],
            label = "thermal power")
plt.xlabel("input_voltage")
plt.ylabel("thermal power")
plt.legend(loc='upper left')
plt.show()

# %%
plt.scatter(data_4b['input_voltage'], data_4b['el_power'],
            label = "electric power")
plt.xlabel("input_voltage")
plt.ylabel("electric power")
plt.legend(loc='upper left')
plt.show()

# %%
plt.scatter(data_4b['th_power'], data_4b['el_power'])
plt.xlabel("thermal power")
plt.ylabel("electric power")
plt.legend(loc='upper left')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data_9 = pp.openCSVFile('experiment_9.csv', temp_data_folder)

# %%
plt.scatter(data_9['input_voltage'], data_9['spinning_soll'],
            label = "Drehzahl")
plt.xlabel("input_voltage")
plt.ylabel("spinning_measured")
plt.legend(loc='upper left')
plt.show()

# %%
plt.scatter(data_9['input_voltage'], data_9['th_power'],
            label = "thermal power")
plt.xlabel("input_voltage")
plt.ylabel("thermal power")
plt.legend(loc='upper left')
plt.show()

# %%
plt.scatter(data_9['input_voltage'], data_9['el_power'],
            label = "electric power")
plt.xlabel("input_voltage")
plt.ylabel("electric power")
plt.legend(loc='upper left')
plt.show()

# %%
plt.scatter(data_9['th_power'], data_9['el_power'])
plt.xlabel("thermal power")
plt.ylabel("electric power")
plt.legend(loc='upper left')
plt.show()
# Out:
# No handles with labels found to put in legend.
